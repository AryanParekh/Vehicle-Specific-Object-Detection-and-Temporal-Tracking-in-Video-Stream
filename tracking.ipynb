# %%
from ultralytics import YOLO

# %%
model = YOLO(r"C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\runs\detect\train\weights\best.pt")

# %%
results_botsort = model.track(source=r"C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\sample2.mp4", show=True, tracker="botsort.yaml", save=True, project="./results_botsort", stream_buffer=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/522) C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\sample2.mp4: 384x640 (no detections), 1916.5ms
# video 1/1 (2/522) C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\sample2.mp4: 384x640 1 traffic sign, 2005.2ms
# video 1/1 (3/522) C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\sample2.mp4: 384x640 1 traffic sign, 1992.3ms
# ...

# %%
results_bytetrack = model.track(source=r"C:\Users\User\Desktop\Aryan\Western University Work\9542\Project\sample2.mp4", show=True, tracker="bytetrack.yaml", save=True, project="./results_bytetrack", stream_buffer=True)
